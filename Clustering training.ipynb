# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as py
# %matplotlib inline

# %%
fifa.describe()
# Out:
#                 age     height_cm     weight_kg       overall     potential  \
# count  18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean      25.283291    181.362184     75.276343     66.244994     71.546887
# std        4.656964      6.756961      7.047744      6.949953      6.139669
# min       16.000000    156.000000     50.000000     48.000000     49.000000
# 25%       22.000000    177.000000     70.000000     62.000000     67.000000
# 50%       25.000000    181.000000     75.000000     66.000000     71.000000
# 75%       29.000000    186.000000     80.000000     71.000000     75.000000
# max       42.000000    205.000000    110.000000     94.000000     95.000000
#
#           value_eur       wage_eur  international_reputation   skill_moves  \
# count  1.827800e+04   18278.000000              18278.000000  18278.000000
# mean   2.484038e+06    9456.942773                  1.103184      2.368038
# ...

# %%
fifa = pd.read_csv("fifa20.csv")
fifa
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
fifa.drop(['sofifa_id','player_url','real_face','body_type','dob', 'loaned_from','joined','nation_position','nation_jersey_number','long_name','pace','shooting','passing','dribbling','defending','physic','gk_diving','gk_handling','work_rate','weak_foot','gk_kicking','gk_reflexes','gk_speed','team_jersey_number','gk_positioning','attacking_crossing','attacking_finishing','attacking_heading_accuracy','attacking_short_passing','attacking_volleys','skill_dribbling','skill_curve','skill_fk_accuracy','skill_long_passing','skill_ball_control','movement_acceleration','movement_balance','power_shot_power','power_jumping','power_stamina','power_strength','power_long_shots','mentality_aggression','mentality_interceptions','mentality_positioning','mentality_vision','mentality_penalties','mentality_composure','defending_marking','defending_standing_tackle','defending_sliding_tackle','goalkeeping_diving','goalkeeping_handling','movement_sprint_speed','movement_agility','movement_reactions','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes','ls','st','rs','lw','lf','cf','rf','rw','lam','cam','ram','lm','lcm','cm','rcm','rm','lwb','ldm','cdm','rdm','rwb','lb','lcb','cb','rcb','rb','player_traits'],axis=1,inplace=True)

# %%
fifa.head(50)
# Out:
#            short_name  age  height_cm  weight_kg     nationality  \
# 0            L. Messi   32        170         72       Argentina
# 1   Cristiano Ronaldo   34        187         83        Portugal
# 2           Neymar Jr   27        175         68          Brazil
# 3            J. Oblak   26        188         87        Slovenia
# 4           E. Hazard   28        175         74         Belgium
# 5        K. De Bruyne   28        181         70         Belgium
# 6       M. ter Stegen   27        187         85         Germany
# 7         V. van Dijk   27        193         92     Netherlands
# 8           L. Modrić   33        172         66         Croatia
# 9            M. Salah   27        175         71           Egypt
# 10          K. Mbappé   20        178         73          France
# 11       K. Koulibaly   28        187         89         Senegal
# 12            H. Kane   25        188         89         England
# ...

# %%
fifa.describe()
# Out:
#                 age     height_cm     weight_kg       overall     potential  \
# count  18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean      25.283291    181.362184     75.276343     66.244994     71.546887
# std        4.656964      6.756961      7.047744      6.949953      6.139669
# min       16.000000    156.000000     50.000000     48.000000     49.000000
# 25%       22.000000    177.000000     70.000000     62.000000     67.000000
# 50%       25.000000    181.000000     75.000000     66.000000     71.000000
# 75%       29.000000    186.000000     80.000000     71.000000     75.000000
# max       42.000000    205.000000    110.000000     94.000000     95.000000
#
#           value_eur       wage_eur  international_reputation   skill_moves  \
# count  1.827800e+04   18278.000000              18278.000000  18278.000000
# mean   2.484038e+06    9456.942773                  1.103184      2.368038
# ...

# %%
fifa['international_reputation'].mode()
fifa['club'].mode()
fifa['nationality'].mode()
fifa['player_positions'].mode()
# Out:
# 0    CB
# dtype: object

# %%
fifa['nationality'].mode()
# Out:
# 0    England
# dtype: object

# %%
fifa.mode()
# Out:
#       short_name   age  height_cm  weight_kg nationality  \
# 0   J. Rodríguez  22.0      180.0       70.0     England
# 1            NaN   NaN        NaN        NaN         NaN
# 2            NaN   NaN        NaN        NaN         NaN
# 3            NaN   NaN        NaN        NaN         NaN
# 4            NaN   NaN        NaN        NaN         NaN
# 5            NaN   NaN        NaN        NaN         NaN
# 6            NaN   NaN        NaN        NaN         NaN
# 7            NaN   NaN        NaN        NaN         NaN
# 8            NaN   NaN        NaN        NaN         NaN
# 9            NaN   NaN        NaN        NaN         NaN
# 10           NaN   NaN        NaN        NaN         NaN
# 11           NaN   NaN        NaN        NaN         NaN
# 12           NaN   NaN        NaN        NaN         NaN
# 13           NaN   NaN        NaN        NaN         NaN
# 14           NaN   NaN        NaN        NaN         NaN
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 18 columns):
# short_name                  18278 non-null object
# age                         18278 non-null int64
# height_cm                   18278 non-null int64
# weight_kg                   18278 non-null int64
# nationality                 18278 non-null object
# club                        18278 non-null object
# overall                     18278 non-null int64
# potential                   18278 non-null int64
# value_eur                   18278 non-null int64
# wage_eur                    18278 non-null int64
# player_positions            18278 non-null object
# preferred_foot              18278 non-null object
# international_reputation    18278 non-null int64
# skill_moves                 18278 non-null int64
# release_clause_eur          16980 non-null float64
# player_tags                 1499 non-null object
# team_position               18038 non-null object
# ...

# %%
np.sum(fifa.isnull())
# Out:
# short_name                      0
# age                             0
# height_cm                       0
# weight_kg                       0
# nationality                     0
# club                            0
# overall                         0
# potential                       0
# value_eur                       0
# wage_eur                        0
# player_positions                0
# preferred_foot                  0
# international_reputation        0
# skill_moves                     0
# release_clause_eur           1298
# player_tags                 16779
# team_position                 240
# contract_valid_until          240
# dtype: int64

# %%
sns.boxplot(fifa['overall'])
plt.show()

# %%
sns.boxplot(fifa['release_clause_eur'])
plt.show()

# %%
sns.boxplot(fifa['weight_kg'])
plt.show()

# %%
bar = fifa['preferred_foot'].value_counts()

sns.barplot(bar.index, bar.values, alpha=1)
plt.show()

# %%
bar.plot.pie(autopct='%1.1f%%',shadow=True)
plt.title('Preferred Foot')
# Out:
# Text(0.5, 1.0, 'Preferred Foot')

# %%
bar5.plot.pie(autopct='%1.1f%%',shadow=True)
plt.title('Preferred Foot')
# Out:
# Text(0.5, 1.0, 'Preferred Foot')

# %%
sns.boxplot(fifa['value_eur'])
plt.show()

# %%
sns.boxplot(fifa['age'])
plt.show()

# %%
best nationality = fifa[fifa['nationality']>50]
gold_medal = data[data['Medal']=='Gold']
sports = gold_medal.groupby(['Sport']).size()
top_gold_medal_sports = pd.DataFrame({'Sports':sports.index, 'Count':sports.values})
#Ranking the count of medalled sport branches in descending order.
top_gold_medal_sports.sort_values(['Count', 'Sports'], ascending=[False, True], inplace=True)

print(top_gold_medal_sports.head())
# Out:
#   File "<ipython-input-64-691a24f4b2af>", line 1
#     best nationality = fifa[fifa['nationality']>50]
#                    ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(18,9))
sns.barplot(x=fifa['club'][:20], y=fifa['Count'][:20])
plt.xticks(rotation= 60)
#plt.xlabel('Sports')
#plt.ylabel('Gold Medal Count')
plt.title('Top 20 Gold Medalled Sports')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Count'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-31b495c093a1> in <module>
#       1 plt.figure(figsize=(18,9))
# ...

# %%
bar8 = fifa['nationality'].value_counts()

bar8.plot.pie(autopct='%1.1f%%',shadow=True)
plt.title('Asal Negara')
# Out:
# Text(0.5, 1.0, 'Asal Negara')

# %%
bar2 = fifa['international_reputation'].value_counts()

sns.barplot(bar2.index, bar2.values, alpha=1)
plt.show()

# %%
bar2.plot.pie(autopct='%1.1f%%',shadow=True)
plt.title('Reputasi di International')
# Out:
# Text(0.5, 1.0, 'Reputasi di International')

# %%
bar3 = fifa['skill_moves'].value_counts()

sns.barplot(bar3.index, bar3.values, alpha=1)
plt.show()

# %%
bar4 = fifa['contract_valid_until'].value_counts()

sns.barplot(bar4.index, bar4.values, alpha=1)
plt.show()

# %%
bar3.plot.pie(autopct='%1.1f%%',shadow=True)
plt.title('Kontrak Bermain')
# Out:
# Text(0.5, 1.0, 'Kontrak Bermain')

# %%
bar4.plot.pie(autopct='%1.1f%%',shadow=True)
plt.title('Kontrak Bermain')
# Out:
# Text(0.5, 1.0, 'Kontrak Bermain')

# %%
bar5 = fifa['team_position'].value_counts()

sns.barplot(bar5.index, bar5.values, alpha=1)
plt.show()

# %%
sns.boxplot(fifa['height_cm'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-b9490af459c2> in <module>
# ----> 1 sns.hist(fifa['height_cm'])
#       2 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'hist'

# %%
fifa.mean()
# Out:
# age                         2.528329e+01
# height_cm                   1.813622e+02
# weight_kg                   7.527634e+01
# overall                     6.624499e+01
# potential                   7.154689e+01
# value_eur                   2.484038e+06
# wage_eur                    9.456943e+03
# international_reputation    1.103184e+00
# skill_moves                 2.368038e+00
# release_clause_eur          4.740717e+06
# contract_valid_until        2.021115e+03
# dtype: float64

# %%
best_nation=fifa['nationality'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True).head(30)
best_nation
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
# Brazil                  824
# Italy                   732
# Colombia                591
# Japan                   453
# Netherlands             416
# China PR                373
# Chile                   370
# Sweden                  358
# Norway                  350
# Republic of Ireland     348
# United States           347
# Denmark                 345
# Portugal                344
# Mexico                  340
# Poland                  324
# Korea Republic          322
# Austria                 319
# Saudi Arabia            310
# Turkey                  294
# Romania                 287
# Scotland                277
# Belgium                 268
# Switzerland             229
# Australia               196
# Uruguay                 164
# Name: nationality, dtype: int64

# %%
plt.figure(figsize=(30,10))
sns.barplot(best_nation.index, best_nation.values, alpha=1)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.barplot(best_nation.values, best_nation.index, alpha=1)
plt.show()

# %%
fifa.drop(fifa[fifa['club']=='Russia'].index,inplace=True)

# %%
fifa.drop(fifa[fifa['club']=='Uruguay'].index,inplace=True)

# %%
fifa.drop(fifa[fifa['club']=='Colombia'].index,inplace=True)

# %%
fifa.drop(fifa[fifa['club']=='Mexico'].index,inplace=True)

# %%
fifa.drop(fifa[fifa['club']=='Netherlands'].index,inplace=True)

# %%
fifa.drop(fifa[fifa['club']=='Turkey'].index,inplace=True)

# %%
fifa.drop(fifa[fifa['club']=='Sweden'].index,inplace=True)

# %%
best_club=fifa.groupby('club',as_index=False).agg({'overall':'mean'}).sort_values(by=['overall'],ascending=False).head(30)
best_club
# Out:
#                     club    overall
# 225    FC Bayern München  81.304348
# 502          Real Madrid  80.121212
# 349             Juventus  80.060606
# 223         FC Barcelona  78.363636
# 77   Bayer 04 Leverkusen  77.280000
# 141              Chelsea  77.060606
# 399      Manchester City  77.000000
# 423               Napoli  76.870968
# 400    Manchester United  76.848485
# 621    Tottenham Hotspur  76.484848
# 63       Atlético Madrid  76.181818
# 407                Milan  76.172414
# 375                Lazio  75.939394
# 459  Paris Saint-Germain  75.909091
# 388            Liverpool  75.848485
# 538           SL Benfica  75.833333
# 340                Inter  75.666667
# 248             FC Porto  75.500000
# 565           Sevilla FC  75.424242
# 645          Valencia CF  75.393939
# 92     Borussia Dortmund  75.322581
# 218              Everton  75.121212
# 52               Arsenal  75.060606
# 671              Watford  75.000000
# 591          Sporting CP  74.900000
# ...

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=best_club['overall'][:30], y=best_club['club'][:30])
plt.xticks(rotation= 60)

plt.show()

# %%
best_young=fifa.groupby('club',as_index=False).agg({'potential':'mean'}).sort_values(by=['potential'],ascending=False).head(30)
best_young
# Out:
#                            club  potential
# 225           FC Bayern München  85.826087
# 502                 Real Madrid  85.727273
# 223                FC Barcelona  85.727273
# 399             Manchester City  84.303030
# 621           Tottenham Hotspur  83.242424
# 349                    Juventus  83.242424
# 63              Atlético Madrid  83.060606
# 459         Paris Saint-Germain  82.939394
# 388                   Liverpool  82.696970
# 52                      Arsenal  82.545455
# 400           Manchester United  82.454545
# 141                     Chelsea  82.363636
# 92            Borussia Dortmund  82.225806
# 444          Olympique Lyonnais  81.896552
# 77          Bayer 04 Leverkusen  81.840000
# 407                       Milan  81.689655
# 538                  SL Benfica  81.600000
# 17                    AS Monaco  81.545455
# 28                         Ajax  81.366667
# 485                  RB Leipzig  81.363636
# 423                      Napoli  80.806452
# ...

# %%
plt.figure(figsize=(18,9))
sns.barplot(x=best_young['potential'][:30], y=best_young['club'][:30])
plt.xticks(rotation= 60)

plt.show()

# %%
plt.barh(best_nation.index, best_nation.Fuel_Type,colors='c')

# %%
best_nation=fifa.groupby('nationality',as_index=False).agg({'overall':'mean'}).sort_values(by=['overall'],ascending=False).head(60)
best_nation
# Out:
#               nationality    overall
# 106            Mozambique  73.250000
# 26                   Chad  73.000000
# 10                Bahrain  72.000000
# 2                 Algeria  71.380000
# 18                 Brazil  71.161408
# 76                 Israel  71.125000
# 47                Eritrea  71.000000
# 90                  Libya  71.000000
# 54                  Gabon  70.687500
# 121              Portugal  70.514535
# 155               Uruguay  70.510638
# 25   Central African Rep.  70.500000
# 24             Cape Verde  70.500000
# 42                Ecuador  70.490566
# 38         Czech Republic  70.313725
# 143                 Syria  70.250000
# 95             Madagascar  70.250000
# 43                  Egypt  70.100000
# 122           Puerto Rico  70.000000
# 144   São Tomé & Príncipe  70.000000
# 136                 Spain  69.953623
# 152               Ukraine  69.869565
# 117              Paraguay  69.787500
# 34                Croatia  69.785714
# ...

# %%
overall_nation=fifa.groupby('nationality',as_index=False).agg({'overall':'mean'})
overall_nation
# Out:
#            nationality    overall
# 0          Afghanistan  62.000000
# 1              Albania  66.418605
# 2              Algeria  71.380000
# 3               Angola  69.375000
# 4    Antigua & Barbuda  59.428571
# ..                 ...        ...
# 157          Venezuela  67.075758
# 158            Vietnam  62.000000
# 159              Wales  64.692308
# 160             Zambia  67.100000
# 161           Zimbabwe  67.250000
#
# [162 rows x 2 columns]

# %%
potent_nation=fifa.groupby('nationality',as_index=False).agg({'potential':'mean'})
potent_nation
# Out:
#            nationality  potential
# 0          Afghanistan  68.000000
# 1              Albania  72.116279
# 2              Algeria  74.240000
# 3               Angola  73.437500
# 4    Antigua & Barbuda  68.571429
# ..                 ...        ...
# 157          Venezuela  72.848485
# 158            Vietnam  67.000000
# 159              Wales  70.316239
# 160             Zambia  73.500000
# 161           Zimbabwe  71.916667
#
# [162 rows x 2 columns]

# %%
y2=potent_nation['potential']
y1=overall_nation['overall']

# %%
y3=overall_nation['nationality']

# %%
plt.scatter(y1, y2)

# %% [markdown]
# ## from sklearn.cluster import KMeans
# cluster_range = range (1,15)
# cluster_error =[]
# for i in cluster_range:
#     cluster=KMeans(i)
#     cluster.fit(y1)
#     labels=cluster.labels_
#     centroid=cluster.cluster_centers_3
#     cluster_errors.append(cluster.inertia_)
# cluster_df=pd.DataFrame({'num_cluster':cluster_range,'cluster_error':cluster_error})
# cluster_df

# %%
from sklearn.cluster import KMeans

# %%
y=pd.concat([y1,y2],axis=1)
y
# Out:
#        overall  potential
# 0    62.000000  68.000000
# 1    66.418605  72.116279
# 2    71.380000  74.240000
# 3    69.375000  73.437500
# 4    59.428571  68.571429
# ..         ...        ...
# 157  67.075758  72.848485
# 158  62.000000  67.000000
# 159  64.692308  70.316239
# 160  67.100000  73.500000
# 161  67.250000  71.916667
#
# [162 rows x 2 columns]

# %%
cluster_range = range (1,15) 
cluster_error =[] 
for i in cluster_range: 
    clusters=KMeans(i) 
    clusters.fit(y) 
    labels=clusters.labels_ 
    centroid=clusters.cluster_centers_,3
    cluster_error.append(clusters.inertia_) 
cluster_df=pd.DataFrame({'num_cluster':cluster_range,'cluster_error':cluster_error}) 
cluster_df
# Out:
#     num_cluster  cluster_error
# 0             1    3467.593359
# 1             2    1391.993157
# 2             3     903.683477
# 3             4     705.851769
# 4             5     572.041236
# 5             6     487.052158
# 6             7     420.732575
# 7             8     356.766958
# 8             9     308.117969
# 9            10     280.974439
# 10           11     247.959345
# 11           12     213.613667
# 12           13     193.216060
# 13           14     175.619169

# %%
dfy=y.iloc[:,[11,12,13,14,15]]
kmeans=KMeans(n_clusters=3).fit(dfy)
centroid=kmeans.cluster_centers_
print(centroid)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-891665fd56cf> in <module>
# ----> 1 dfy=y.iloc[:,[11,12,13,14,15]]
#       2 kmeans=KMeans(n_clusters=3).fit(dfy)
#       3 centroid=kmeans.cluster_centers_
#       4 print(centroid)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2090     def _getitem_tuple(self, tup):
#    2091
# -> 2092         self._has_valid_tuple(tup)
#    2093         try:
#    2094             return self._getitem_lowerdim(tup)
#
# ...

# %%
# Import the KElbowVisualizer method 
from yellowbrick.cluster import KElbowVisualizer

# Instantiate a scikit-learn K-Means model
model = KMeans(random_state=0)

# Instantiate the KElbowVisualizer with the number of clusters and the metric 
visualizer = KElbowVisualizer(model, k=(2,6), metric='silhouette', timings=False)

# Fit the data and visualize
visualizer.fit(y)    
visualizer.poof()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\yellowbrick\utils\kneed.py:182: YellowbrickWarning:
#
# No "knee" or "elbow point" detected This could be due to bad clustering, no actual clusters being formed etc.
#
# C:\Users\User\Anaconda3\lib\site-packages\yellowbrick\utils\kneed.py:140: YellowbrickWarning:
#
# No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#
# C:\Users\User\Anaconda3\lib\site-packages\yellowbrick\cluster\elbow.py:343: YellowbrickWarning:
#
# No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning

# %%
Data={'x':[12,20,28,18,29,33,24,45,45,52,51,52,55,53,55,61,64,69,72],
      'y':[39,36,30,52,54,46,55,59,63,70,66,63,58,23,14,8,19,7,24]}
df=pd(Data,columns=['x','y'])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-d5bbf3f6646c> in <module>
#       1 Data={'x':[12,20,28,18,29,33,24,45,45,52,51,52,55,53,55,61,64,69,72],
#       2       'y':[39,36,30,52,54,46,55,59,63,70,66,63,58,23,14,8,19,7,24]}
# ----> 3 df=pd(Data,columns=['x','y'])
#       4 df
#
# TypeError: 'module' object is not callable

# %%
kmeans=KMeans(n_clusters=3).fit(y)
centroids=kmeans.cluster_centers_
centroids=np.array(centroids)
centroids
# Out:
# array([[61.24554064, 64.38428142],
#        [69.11884435, 73.19004689],
#        [64.70366233, 69.28205147]])

# %%
C1=centroids[0,:]
C2=centroids[1,:]
C3=centroids[2,:]

# %%
# calculate the Euclidean diatance between the data 

def calculate_distance(centroid, X, Y):
    distances = []
        
    # Unpack the x and y coordinates of the centroid
    c_x, c_y = centroid
        
    # Iterate over the data points and calculate the distance
    for x, y in list(zip(X, Y)):
        root_diff_x = (x - c_x) ** 2
        root_diff_y = (y - c_y) ** 2
        distance = np.sqrt(root_diff_x + root_diff_y)
        distances.append(distance)
    
    return distances

# %%
# Calculate the distance and assign them to the DataFrame accordingly

y['C1_Distance'] = calculate_distance(C1, y.potential, y.overall)
y['C2_Distance'] = calculate_distance(C2, y.potential, y.overall)
y['C3_Distance'] = calculate_distance(C3, y.potential, y.overall)

# Preview the data
print(y)
# Out:
#        overall  potential  C1_Distance  C2_Distance  C3_Distance
# 0    62.000000  68.000000     7.162927    11.245842     7.993379
# 1    66.418605  72.116279    11.059450     7.405204     7.946459
# 2    71.380000  74.240000    14.757915     5.431621     9.764380
# 3    69.375000  73.437500    13.173881     5.762410     8.734332
# 4    59.428571  68.571429     8.844642    13.772359    10.585400
# ..         ...        ...          ...          ...          ...
# 157  67.075758  72.848485    11.911018     7.162035     8.438357
# 158  62.000000  67.000000     6.228852    11.388883     7.635538
# 159  64.692308  70.316239     9.075927     8.581686     7.250294
# 160  67.100000  73.500000    12.551769     7.502213     9.062941
# 161  67.250000  71.916667    11.049220     6.565970     7.493775
#
# [162 rows x 5 columns]

# %%
# Get the minimum distance centroids
y['Cluster'] = y[['C1_Distance', 'C2_Distance', 'C3_Distance']].apply(np.argmin, axis =1)
    
# Map the centroids accordingly and rename them
y['Cluster'] = y['Cluster'].map({'C1_Distance': 'C1', 'C2_Distance': 'C2', 'C3_Distance': 'C3'})
    
# Get a preview of the data
print(y)
# Out:
#        overall  potential  C1_Distance  C2_Distance  C3_Distance Cluster
# 0    62.000000  68.000000     7.162927    11.245842     7.993379      C1
# 1    66.418605  72.116279    11.059450     7.405204     7.946459      C2
# 2    71.380000  74.240000    14.757915     5.431621     9.764380      C2
# 3    69.375000  73.437500    13.173881     5.762410     8.734332      C2
# 4    59.428571  68.571429     8.844642    13.772359    10.585400      C1
# ..         ...        ...          ...          ...          ...     ...
# 157  67.075758  72.848485    11.911018     7.162035     8.438357      C2
# 158  62.000000  67.000000     6.228852    11.388883     7.635538      C1
# 159  64.692308  70.316239     9.075927     8.581686     7.250294      C3
# 160  67.100000  73.500000    12.551769     7.502213     9.062941      C2
# 161  67.250000  71.916667    11.049220     6.565970     7.493775      C2
#
# [162 rows x 6 columns]
# ...

# %%
y4=y['Cluster']

# %%
yy=pd.concat([y3,y],axis=1)
yy
# Out:
#            nationality    overall  potential  C1_Distance  C2_Distance  \
# 0          Afghanistan  62.000000  68.000000     7.162927    11.245842
# 1              Albania  66.418605  72.116279    11.059450     7.405204
# 2              Algeria  71.380000  74.240000    14.757915     5.431621
# 3               Angola  69.375000  73.437500    13.173881     5.762410
# 4    Antigua & Barbuda  59.428571  68.571429     8.844642    13.772359
# ..                 ...        ...        ...          ...          ...
# 157          Venezuela  67.075758  72.848485    11.911018     7.162035
# 158            Vietnam  62.000000  67.000000     6.228852    11.388883
# 159              Wales  64.692308  70.316239     9.075927     8.581686
# 160             Zambia  67.100000  73.500000    12.551769     7.502213
# 161           Zimbabwe  67.250000  71.916667    11.049220     6.565970
#
#      C3_Distance Cluster
# 0       7.993379      C1
# 1       7.946459      C2
# 2       9.764380      C2
# ...

# %%
yy.to_csv(r'D:\Document\Akademik\Semester 6\Data Mining\Hasil cluster.csv', index=False)

# %%
plt.scatter(y['overall'],y['potential'],c=kmeans.labels_.astype(float),s=50,alpha=1)
plt.scatter(centroids[:,0],centroids[:,1],c='red',s=50)
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# %%
feature=pd.concat([fifa.age,fifa.weight_kg,fifa.height_cm,fifa.overall,fifa.potential,fifa.value_eur,fifa.wage_eur],axis=1)
feature
# Out:
#        age  weight_kg  height_cm  overall  potential  value_eur  wage_eur
# 0       32         72        170       94         94   95500000    565000
# 1       34         83        187       93         93   58500000    405000
# 2       27         68        175       92         92  105500000    290000
# 3       26         87        188       91         93   77500000    125000
# 4       28         74        175       91         91   90000000    470000
# ...    ...        ...        ...      ...        ...        ...       ...
# 18273   22         79        186       48         56      40000      2000
# 18274   22         66        177       48         56      40000      2000
# 18275   19         75        186       48         56      40000      1000
# 18276   18         74        185       48         54      40000      1000
# 18277   26         78        182       48         51      40000      2000
#
# [18238 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(feature)

# %%
#Calculate covariance matrix
cov_mat = np.cov(X_std.T)

#Calculate covariance matrix (in addition)
#mean_vec = np.mean(X_std, axis=0)
#cov_mat = (X_std - mean_vec).T.dot((X_std - mean_vec)) / (X_std.shape[0]-1)

#Perform eigen decomposition on covariance matrix
eig_vals, eig_vecs = np.linalg.eig(cov_mat)
print('\nEigenvalues \n%s' %eig_vals)
print('Eigenvectors \n%s' %eig_vecs)
# Out:
# Eigenvalues
# [2.94879837 1.84150711 1.18431128 0.61607413 0.06263761 0.21469951
#  0.13235583]
# Eigenvectors
# [[-0.13979057 -0.30737692  0.79334316  0.09230785 -0.48162851 -0.11750816
#    0.04785111]
#  [-0.11274603 -0.66495552 -0.17955447  0.01060801 -0.01037108  0.71594273
#    0.00941254]
#  [-0.06781782 -0.63651982 -0.34102185 -0.04966935  0.02047619 -0.6861521
#   -0.01601051]
#  [-0.50581499 -0.03607083  0.23988178  0.48743524  0.66437675 -0.0497798
#   -0.06196142]
#  [-0.42698079  0.19865317 -0.40167302  0.53328259 -0.54240291 -0.00180352
#    0.19567478]
#  [-0.52393992  0.10833419 -0.05262927 -0.38909645 -0.155412    0.01804134
#   -0.73150967]
#  [-0.50047301  0.0754693   0.02041061 -0.56171185  0.08807314 -0.00252354
#    0.64817521]]

# %%
#Calculate Eigen Using Sklearn (As Performed Above)
pca=PCA(n_components=7)
X_pca = pca.fit(X_std).transform(X_std)
print('\nEigenvalues \n%s' %pca.explained_variance_)
print('Eigenvectors \n%s' %pca.components_)
# Out:
# Eigenvalues
# [2.94879837 1.84150711 1.18431128 0.61607413 0.21469951 0.13235583
#  0.06263761]
# Eigenvectors
# [[ 0.13979057  0.11274603  0.06781782  0.50581499  0.42698079  0.52393992
#    0.50047301]
#  [-0.30737692 -0.66495552 -0.63651982 -0.03607083  0.19865317  0.10833419
#    0.0754693 ]
#  [ 0.79334316 -0.17955447 -0.34102185  0.23988178 -0.40167302 -0.05262927
#    0.02041061]
#  [-0.09230785 -0.01060801  0.04966935 -0.48743524 -0.53328259  0.38909645
#    0.56171185]
#  [-0.11750816  0.71594273 -0.6861521  -0.0497798  -0.00180352  0.01804134
#   -0.00252354]
#  [-0.04785111 -0.00941254  0.01601051  0.06196142 -0.19567478  0.73150967
#   -0.64817521]
#  [ 0.48162851  0.01037108 -0.02047619 -0.66437675  0.54240291  0.155412
#   -0.08807314]]

# %%
#Print Scree Plot
eigen_val = pca.explained_variance_
plt.xlabel('Principal Component')
plt.ylabel('Eigenvalue')
plt.title('Scree Plot of PCA: Component Eigen Values')
plt.plot(eigen_val)
print(eigen_val)
# Out:
# [2.94879837 1.84150711 1.18431128 0.61607413 0.21469951 0.13235583
#  0.06263761]

# %%
#cumulative variance explains (proportion)
var1=np.cumsum(np.round(pca.explained_variance_ratio_,decimals=4)*100)
plt.xlabel('Principal Component')
plt.ylabel('Cumulative Variance')
plt.title('Explained Variance of PCA by Component')
plt.plot(var1)
print(var1)
# Out:
# [ 42.12  68.43  85.35  94.15  97.22  99.11 100.  ]

# %%
#looking at above plot (i'm taking 30variables)
pca=PCA(n_components=3)
pca.fit(X_std)
x1=pca.fit_transform(X_std)
print(x1)
# Out:
# [[25.35160003  5.28143796  0.9485685 ]
#  [18.40084558  1.20109467  0.37779621]
#  [19.3995174   4.68641468 -0.34921364]
#  ...
#  [-2.98350064 -0.48246191 -0.89504438]
#  [-3.17870385 -0.29261361 -0.85868149]
#  [-3.08981086 -1.00938464  0.75178121]]

# %%
feature1=pd.DataFrame(x1)
feature1.columns  = ['Component 1', 'Component 2','Component 3']
feature1.head()
# Out:
#    Component 1  Component 2  Component 3
# 0    25.351600     5.281438     0.948569
# 1    18.400846     1.201095     0.377796
# 2    19.399517     4.686415    -0.349214
# 3    13.312048     0.647633    -1.653740
# 4    22.145841     4.362406     0.017095

# %%
#Examining the component loadings or components
PC = pca.components_
PC_trans = PC.transpose()
results = pd.DataFrame(PC_trans)
results.columns = ['Component 1', 'Component 2','Component 3']
results.index=feature.columns
results
# Out:
#            Component 1  Component 2  Component 3
# age           0.139791    -0.307377     0.793343
# weight_kg     0.112746    -0.664956    -0.179554
# height_cm     0.067818    -0.636520    -0.341022
# overall       0.505815    -0.036071     0.239882
# potential     0.426981     0.198653    -0.401673
# value_eur     0.523940     0.108334    -0.052629
# wage_eur      0.500473     0.075469     0.020411

# %%
results.to_csv(r'D:\Document\Akademik\Semester 6\Data Mining\Hasil PC.csv', index=False)
