# %%
import numpy as np 
import pandas as pd 

import os

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data18 = pd.read_excel("D:/Document/Akademik//Semester 7/KP/analisis 2018.xlsx")
data18
# Out:
#      KAB/KOTA JENIS KELAMIN  USIA              JENIS PELATIHAN  \
# 0      KEDIRI             P    45  AKUNTANSI BERBASIS KOMPUTER
# 1      KEDIRI             P    51  AKUNTANSI BERBASIS KOMPUTER
# 2      KEDIRI             P    52  AKUNTANSI BERBASIS KOMPUTER
# 3      KEDIRI             P    43  AKUNTANSI BERBASIS KOMPUTER
# 4      KEDIRI             P    42  AKUNTANSI BERBASIS KOMPUTER
# ...       ...           ...   ...                          ...
# 1843     BATU             P    34                        KASIR
# 1844     BATU             P    25                        KASIR
# 1845     BATU             P    39                        KASIR
# 1846  JOMBANG             P    42                        KASIR
# 1847     BATU             P    35                        KASIR
#
#      JANGKAUAN PEMASARAN Jenis Produk Koperasi  VOLUME USAHA 1 TAHUN  \
# 0                    NaN         Simpan Pinjam                   NaN
# ...

# %%
# Fill missing value with mean
data18['VOLUME USAHA 1 TAHUN']=data18['VOLUME USAHA 1 TAHUN'].fillna((data18['VOLUME USAHA 1 TAHUN'].mean()))

np.sum(data18.isnull())
# Out:
# KAB/KOTA                   0
# JENIS KELAMIN              0
# USIA                       0
# JENIS PELATIHAN            0
# JANGKAUAN PEMASARAN      793
# Jenis Produk Koperasi    459
# VOLUME USAHA 1 TAHUN       0
# TAHUN MEMULAI USAHA      742
# dtype: int64

# %%
data18['TAHUN MEMULAI USAHA']=data18['TAHUN MEMULAI USAHA'].fillna((data18['TAHUN MEMULAI USAHA'].mean()))

np.sum(data18.isnull())
# Out:
# KAB/KOTA                   0
# JENIS KELAMIN              0
# USIA                       0
# JENIS PELATIHAN            0
# JANGKAUAN PEMASARAN      793
# Jenis Produk Koperasi    459
# VOLUME USAHA 1 TAHUN       0
# TAHUN MEMULAI USAHA        0
# dtype: int64

# %%
data18['JANGKAUAN PEMASARAN']=data18['JANGKAUAN PEMASARAN'].fillna((data18['JANGKAUAN PEMASARAN'].mode()[0]))

np.sum(data18.isnull())
# Out:
# KAB/KOTA                   0
# JENIS KELAMIN              0
# USIA                       0
# JENIS PELATIHAN            0
# JANGKAUAN PEMASARAN        0
# Jenis Produk Koperasi    459
# VOLUME USAHA 1 TAHUN       0
# TAHUN MEMULAI USAHA        0
# dtype: int64

# %%
data18['Jenis Produk Koperasi']=data18['Jenis Produk Koperasi'].fillna((data18['Jenis Produk Koperasi'].mode()[0]))

np.sum(data18.isnull())
# Out:
# KAB/KOTA                 0
# JENIS KELAMIN            0
# USIA                     0
# JENIS PELATIHAN          0
# JANGKAUAN PEMASARAN      0
# Jenis Produk Koperasi    0
# VOLUME USAHA 1 TAHUN     0
# TAHUN MEMULAI USAHA      0
# dtype: int64

# %%
data18.to_excel(r'D:\Document\Akademik\Semester 7\KP\analisis 2018 new.xlsx', index=False)

# %%
data18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1848 entries, 0 to 1847
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   KAB/KOTA               1848 non-null   object
#  1   JENIS KELAMIN          1848 non-null   object
#  2   USIA                   1848 non-null   int64
#  3   JENIS PELATIHAN        1848 non-null   object
#  4   JANGKAUAN PEMASARAN    1055 non-null   object
#  5   Jenis Produk Koperasi  1389 non-null   object
#  6   VOLUME USAHA 1 TAHUN   816 non-null    float64
#  7   TAHUN MEMULAI USAHA    1106 non-null   float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 115.6+ KB

# %%
np.sum(data18.isnull())
# Out:
# KAB/KOTA                    0
# JENIS KELAMIN               0
# USIA                        0
# JENIS PELATIHAN             0
# JANGKAUAN PEMASARAN       793
# Jenis Produk Koperasi     459
# VOLUME USAHA 1 TAHUN     1032
# TAHUN MEMULAI USAHA       742
# dtype: int64

# %%
data18.mode()
# Out:
#   KAB/KOTA JENIS KELAMIN  USIA        JENIS PELATIHAN JANGKAUAN PEMASARAN  \
# 0  MAGETAN             P    50  AKUNTANSI BERBASIS IT               LOKAL
#
#   Jenis Produk Koperasi  VOLUME USAHA 1 TAHUN  TAHUN MEMULAI USAHA
# 0         Simpan Pinjam            50000000.0               2010.0

# %%
data18.describe()
# Out:
#               USIA  VOLUME USAHA 1 TAHUN  TAHUN MEMULAI USAHA
# count  1848.000000          8.160000e+02          1106.000000
# mean     44.198052          2.172609e+09          2005.315552
# std      10.444623          1.380959e+10            61.371304
# min      19.000000          0.000000e+00             0.000000
# 25%      37.000000          4.800075e+07          2006.000000
# 50%      45.000000          1.632506e+08          2010.000000
# 75%      51.000000          7.000000e+08          2014.000000
# max      81.000000          2.400000e+11          2018.000000

# %%
data19 = pd.read_excel("D:/Document/Akademik//Semester 7/KP/analisis 2019.xlsx")
data19
# Out:
#       KAB/KOTA  USIA                         JENIS PELATIHAN JENIS KELAMIN  \
# 0      JOMBANG    39  AKUNTANSI BERBASIS TEKNOLOGI INFORMASI             P
# 1      JOMBANG    56  AKUNTANSI BERBASIS TEKNOLOGI INFORMASI             P
# 2      JOMBANG    38  AKUNTANSI BERBASIS TEKNOLOGI INFORMASI             P
# 3      JOMBANG    40  AKUNTANSI BERBASIS TEKNOLOGI INFORMASI             P
# 4      JOMBANG    45  AKUNTANSI BERBASIS TEKNOLOGI INFORMASI             P
# ...        ...   ...                                     ...           ...
# 1227  LAMONGAN    20     KEWIRAUSAHAAN BAGI PEMUDA/MAHASISWA             L
# 1228  LAMONGAN    22     KEWIRAUSAHAAN BAGI PEMUDA/MAHASISWA             L
# 1229  LAMONGAN    23     KEWIRAUSAHAAN BAGI PEMUDA/MAHASISWA             P
# 1230  LAMONGAN    19     KEWIRAUSAHAAN BAGI PEMUDA/MAHASISWA             L
# 1231  LAMONGAN    23     KEWIRAUSAHAAN BAGI PEMUDA/MAHASISWA             L
#
# ...

# %%
# Fill missing value with mean
data19['VOLUME USAHA 1 TAHUN']=data19['VOLUME USAHA 1 TAHUN'].fillna((data19['VOLUME USAHA 1 TAHUN'].mean()))

np.sum(data19.isnull())
# Out:
# KAB/KOTA                   0
# USIA                       0
# JENIS PELATIHAN            0
# JENIS KELAMIN              0
# JANGKAUAN PEMASARAN      214
# Jenis Produk Koperasi    166
# VOLUME USAHA 1 TAHUN       0
# TAHUN MEMULAI USAHA      319
# dtype: int64

# %%
data19['TAHUN MEMULAI USAHA']=data19['TAHUN MEMULAI USAHA'].fillna((data19['TAHUN MEMULAI USAHA'].mean()))

np.sum(data19.isnull())
# Out:
# KAB/KOTA                   0
# USIA                       0
# JENIS PELATIHAN            0
# JENIS KELAMIN              0
# JANGKAUAN PEMASARAN      214
# Jenis Produk Koperasi    166
# VOLUME USAHA 1 TAHUN       0
# TAHUN MEMULAI USAHA        0
# dtype: int64

# %%
data19['Jenis Produk Koperasi']=data19['Jenis Produk Koperasi'].fillna((data19['Jenis Produk Koperasi'].mode()[0]))

np.sum(data19.isnull())
# Out:
# KAB/KOTA                   0
# USIA                       0
# JENIS PELATIHAN            0
# JENIS KELAMIN              0
# JANGKAUAN PEMASARAN      214
# Jenis Produk Koperasi      0
# VOLUME USAHA 1 TAHUN       0
# TAHUN MEMULAI USAHA        0
# dtype: int64

# %%
data19['JANGKAUAN PEMASARAN']=data19['JANGKAUAN PEMASARAN'].fillna((data19['JANGKAUAN PEMASARAN'].mode()[0]))

np.sum(data19.isnull())
# Out:
# KAB/KOTA                 0
# USIA                     0
# JENIS PELATIHAN          0
# JENIS KELAMIN            0
# JANGKAUAN PEMASARAN      0
# Jenis Produk Koperasi    0
# VOLUME USAHA 1 TAHUN     0
# TAHUN MEMULAI USAHA      0
# dtype: int64

# %%
data19.to_excel(r'D:\Document\Akademik\Semester 7\KP\analisis 2019 new.xlsx', index=False)

# %%
data19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232 entries, 0 to 1231
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   KAB/KOTA              1232 non-null   object
#  1   USIA                  1232 non-null   int64
#  2   JENIS PELATIHAN       1232 non-null   object
#  3   JENIS KELAMIN         1232 non-null   object
#  4   JANGKAUAN PEMASARAN   1018 non-null   object
#  5   Jenis Usaha Koperasi  1066 non-null   object
#  6   VOLUME USAHA 1 TAHUN  849 non-null    float64
#  7   TAHUN MEMULAI USAHA   913 non-null    float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 77.1+ KB

# %%
data19.describe()
# Out:
#               USIA  VOLUME USAHA 1 TAHUN  TAHUN MEMULAI USAHA
# count  1232.000000          8.490000e+02           913.000000
# mean     35.500812          3.741369e+09          2005.684556
# std      13.394532          1.718274e+10            12.706675
# min      18.000000          2.325900e+04          1919.000000
# 25%      22.000000          1.500000e+07          1999.000000
# 50%      34.000000          9.600000e+07          2010.000000
# 75%      47.000000          4.981559e+08          2015.000000
# max      72.000000          1.230000e+11          2019.000000

# %%
np.sum(data19.isnull())
# Out:
# KAB/KOTA                  0
# USIA                      0
# JENIS PELATIHAN           0
# JENIS KELAMIN             0
# JANGKAUAN PEMASARAN     214
# Jenis Usaha Koperasi    166
# VOLUME USAHA 1 TAHUN    383
# TAHUN MEMULAI USAHA     319
# dtype: int64

# %%
data19.mode()
# Out:
#    KAB/KOTA  USIA                      JENIS PELATIHAN JENIS KELAMIN  \
# 0  SURABAYA    21  KEWIRAUSAHAAN BAGI PEMUDA/MAHASISWA             P
#
#   JANGKAUAN PEMASARAN Jenis Usaha Koperasi  VOLUME USAHA 1 TAHUN  \
# 0               LOKAL             Konsumsi            12000000.0
#
#    TAHUN MEMULAI USAHA
# 0               2016.0

# %%
data20 = pd.read_excel("D:/Document/Akademik//Semester 7/KP/analisis 2020.xlsx")
data20
# Out:
#         KAB/KOTA JENIS KELAMIN                      JABATAN  USIA  \
# 0     BANYUWANGI             P                     KARYAWAN    42
# 1     BANYUWANGI             P                     KARYAWAN    51
# 2     BANYUWANGI             P                     KARYAWAN    36
# 3     BANYUWANGI             P                     KARYAWAN    44
# 4     BANYUWANGI             P                     KARYAWAN    54
# ..           ...           ...                          ...   ...
# 111  PROBOLINGGO             L                        KETUA    38
# 112  PROBOLINGGO             L  KOOR. UNIT USAHA PERCETAKAN    24
# 113     LUMAJANG             L                   SEKRETARIS    48
# 114  PROBOLINGGO             L                      ANGGOTA    25
# 115  PROBOLINGGO             L             PENANGGUNG JAWAB    42
#
#     JANGKAUAN PEMASARAN                                    JENIS PELATIHAN  \
# 0              REGIONAL  ONE VILLAGE ONE PRODUCT (OVOP) KERAJINAN ANYAM...
# ...

# %%
data20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   KAB/KOTA              116 non-null    object
#  1   JENIS KELAMIN         116 non-null    object
#  2   JABATAN               116 non-null    object
#  3   USIA                  116 non-null    int64
#  4   JANGKAUAN PEMASARAN   116 non-null    object
#  5   JENIS PELATIHAN       116 non-null    object
#  6   Jenis Produk          113 non-null    object
#  7   VOLUME USAHA 1 TAHUN  44 non-null     float64
#  8   TAHUN MEMULAI USAHA   92 non-null     float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 8.3+ KB

# %%
# Fill missing value with mean
data20['VOLUME USAHA 1 TAHUN']=data20['VOLUME USAHA 1 TAHUN'].fillna((data20['VOLUME USAHA 1 TAHUN'].mean()))

np.sum(data20.isnull())
# Out:
# KAB/KOTA                  0
# JENIS KELAMIN             0
# JABATAN                   0
# USIA                      0
# JANGKAUAN PEMASARAN       0
# JENIS PELATIHAN           0
# Jenis Produk Koperasi     3
# VOLUME USAHA 1 TAHUN      0
# TAHUN MEMULAI USAHA      24
# dtype: int64

# %%
data20['TAHUN MEMULAI USAHA']=data20['TAHUN MEMULAI USAHA'].fillna((data20['TAHUN MEMULAI USAHA'].mean()))

np.sum(data20.isnull())
# Out:
# KAB/KOTA                 0
# JENIS KELAMIN            0
# JABATAN                  0
# USIA                     0
# JANGKAUAN PEMASARAN      0
# JENIS PELATIHAN          0
# Jenis Produk Koperasi    3
# VOLUME USAHA 1 TAHUN     0
# TAHUN MEMULAI USAHA      0
# dtype: int64

# %%
data20['Jenis Produk Koperasi']=data20['Jenis Produk Koperasi'].fillna((data20['Jenis Produk Koperasi'].mode()[0]))

np.sum(data20.isnull())
# Out:
# KAB/KOTA                 0
# JENIS KELAMIN            0
# JABATAN                  0
# USIA                     0
# JANGKAUAN PEMASARAN      0
# JENIS PELATIHAN          0
# Jenis Produk Koperasi    0
# VOLUME USAHA 1 TAHUN     0
# TAHUN MEMULAI USAHA      0
# dtype: int64

# %%
data20.to_excel(r'D:\Document\Akademik\Semester 7\KP\analisis 2020 new.xlsx', index=False)

# %%
data20.describe()
# Out:
#              USIA  VOLUME USAHA 1 TAHUN  TAHUN MEMULAI USAHA
# count  116.000000          4.400000e+01            92.000000
# mean    35.344828          3.362909e+08          2016.554348
# std     10.866065          1.800803e+09             9.388284
# min     18.000000          1.000000e+06          1936.000000
# 25%     25.000000          1.000000e+07          2016.000000
# 50%     36.000000          5.000000e+07          2019.000000
# 75%     45.000000          8.585000e+07          2020.000000
# max     59.000000          1.200000e+10          2020.000000

# %%
data20.mode()
# Out:
#      KAB/KOTA JENIS KELAMIN   JABATAN  USIA JANGKAUAN PEMASARAN  \
# 0  BANYUWANGI             L  KARYAWAN    32               LOKAL
#
#                                      JENIS PELATIHAN Jenis Produk  \
# 0  ONE VILLAGE ONE PRODUCT (OVOP) KERAJINAN ANYAM...     Produksi
#
#    VOLUME USAHA 1 TAHUN  TAHUN MEMULAI USAHA
# 0            50000000.0               2020.0

# %%
kabkota=data['KAB/KOTA'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
kabkota
# Out:
# MAGETAN             126
# KOTA MADIUN         119
# SIDOARJO             96
# KEDIRI               82
# BANYUWANGI           81
# KOTA MOJOKERTO       75
# PAMEKASAN            75
# GRESIK               74
# TUBAN                73
# JEMBER               73
# NGANJUK              68
# PROBOLINGGO          68
# PONOROGO             67
# TULUNGAGUNG          67
# LAMONGAN             65
# NGAWI                64
# KOTA KEDIRI          64
# SAMPANG              63
# KOTA PASURUAN        62
# LUMAJANG             60
# MALANG               60
# BATU                 58
# SURABAYA             49
# PASURUAN             26
# BOJONEGORO           23
# KOTA MALANG          17
# KOTA PROBOLINGGO     11
# MOJOKERTO            11
# SITUBONDO            11
# BLITAR               11
# JOMBANG              10
# MADIUN               10
# BONDOWOSO             8
# SUMENEP               6
# TRENGGALEK            6
# BANGKALAN             4
# KOTA BLITAR           3
# PACITAN               2
# ...

# %%
jang=data['JANGKAUAN PEMASARAN'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
jang
# Out:
# KABUPATEN        514
# DESA             169
# KECAMATAN        100
# PROVINSI          99
# NASIONAL          91
# INSTANSI          78
# INTERNASIONAL      4
# Name: JANGKAUAN PEMASARAN, dtype: int64

# %%
df2 = pd.DataFrame([data['KAB/KOTA'].value_counts())
df
# Out:
#   File "<ipython-input-30-82105a5daed2>", line 1
#     df2 = pd.DataFrame([data['KAB/KOTA'].value_counts())
#                                                        ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(15,10))
sns.barplot(kabkota.values, kabkota.index, alpha=1)
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2018")
plt.show()

# %%
pie1=datapie1['KAB/KOTA'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
pie1
# Out:
# KAB/KOTA LAINNYA    159
# MAGETAN             126
# KOTA MADIUN         119
# SIDOARJO             96
# KEDIRI               82
# BANYUWANGI           81
# KOTA MOJOKERTO       75
# PAMEKASAN            75
# GRESIK               74
# JEMBER               73
# TUBAN                73
# PROBOLINGGO          68
# NGANJUK              68
# PONOROGO             67
# TULUNGAGUNG          67
# LAMONGAN             65
# NGAWI                64
# KOTA KEDIRI          64
# SAMPANG              63
# KOTA PASURUAN        62
# MALANG               60
# LUMAJANG             60
# BATU                 58
# SURABAYA             49
# Name: KAB/KOTA, dtype: int64

# %%
g=sns.barplot(kabkota.values, kabkota.index, alpha=1)
for index, row in kabkota.iterrows():
    g.text(row.name,row.survived, round(row.survived,2), color='black', ha="center")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-9341a408fd04> in <module>
#       1 g=sns.barplot(kabkota.values, kabkota.index, alpha=1)
# ----> 2 for index, row in kabkota.iterrows():
#       3     g.text(row.name,row.survived, round(row.survived,2), color='black', ha="center")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'iterrows'

# %%
pie1.plot.pie(autopct='%.1f%%', shadow=True, startangle=90, fontsize="large")
plt.title('Persentase Jumlah Peserta Pelatihan Dinas Koperasi dan UKM di Kabupaten/Kota Jawa Timur 2018')
# Out:
# Text(0.5, 1.0, 'Persentase Jumlah Peserta Pelatihan Dinas Koperasi dan UKM di Kabupaten/Kota Jawa Timur 2018')

# %%
kabkota.plot.pie(autopct='%.1f%%', shadow=True, startangle=140, fontsize="large")
plt.title('Kabupaten/Kota')
# Out:
# Text(0.5, 1.0, 'Kabupaten/Kota')

# %%
datapie11 = pd.read_excel("D:/Document/Akademik/KP/18 piechart.xlsx")
datapie11.head()
# Out:
#               KAB/KOTA
# 0  BAKORWIL BOJONEGORO
# 1  BAKORWIL BOJONEGORO
# 2  BAKORWIL BOJONEGORO
# 3  BAKORWIL BOJONEGORO
# 4  BAKORWIL BOJONEGORO

# %%
pie11=datapie11['KAB/KOTA'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
pie11
# Out:
# BAKORWIL MADIUN        543
# BAKORWIL BOJONEGORO    403
# BAKORWIL PAMEKASAN     367
# BAKORWIL JEMBER        312
# BAKORWIL MALANG        223
# Name: KAB/KOTA, dtype: int64

# %%
pie11.plot.pie(autopct='%.1f%%', shadow=True, startangle=90, fontsize="large")
plt.title('Persentase Jumlah Peserta Pelatihan Dinas Koperasi dan UKM di Kabupaten/Kota Jawa Timur 2018')
# Out:
# Text(0.5, 1.0, 'Persentase Jumlah Peserta Pelatihan Dinas Koperasi dan UKM di Kabupaten/Kota Jawa Timur 2018')

# %%
datapie1 = pd.read_excel("D:/Document/Akademik/KP/2018 piechart.xlsx")
datapie1.head()
# Out:
#   KAB/KOTA
# 0   KEDIRI
# 1   KEDIRI
# 2   KEDIRI
# 3   KEDIRI
# 4   KEDIRI

# %%
 plt.rcParams['figure.figsize']=[15,8]

# %%
plt.figure(figsize=(15,10))
sns.barplot(jang.values, jang.index, alpha=1)
plt.show()

# %%
jk=data['JENIS KELAMIN'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
jk
# Out:
# P    1339
# L     509
# Name: JENIS KELAMIN, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.barplot(jk.index, jk.values, alpha=1)
plt.show()

# %%
pel=data['JENIS PELATIHAN'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
pel
# Out:
# AKUNTANSI BERBASIS IT                             196
# AKUNTANSI BERBASIS KOMPUTER                       180
# MANAJEMEN SYARIAH DAN PENGAWASAN                  120
# PENGAWASAN DAN PENILAIAN KESEHATAN KOPERASI       120
# PELATIHAN DAN UJI SKKNI                           111
# STUDI KELAYAKAN                                    90
# PENGAWASAN KOPERASI                                61
# BISNIS RITEL                                       61
# MANAJEMEN SYARIAH DAN LAPORAN KEUANGAN             60
# BISNIS PLAN                                        60
# BISNIS PLAN DAN PENGAWASAN KOPERASI                60
# PENGAWASAN DAN MANAJEMEN PARTISIPASI (ZOPP)        60
# STUDI KELAYAKAN DAN MANAJEMEN SYARIAH              60
# BISNIS PLAN, KEMASAN DAN KUE KERING                55
# STUDI KELAYAKAN USAHA, KEMASAN DAN OALHAN IKAN     50
# BATIK WARNA ALAM                                   50
# PELATIHAN HANDYCRAFT                               49
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(pel.values, pel.index, alpha=1)
plt.show()

# %%
#2019

# %%
datapie2 = pd.read_excel("D:/Document/Akademik/KP/2019 piechartt.xlsx")
datapie2.head()
# Out:
#   KAB/KOTA
# 0  JOMBANG
# 1  JOMBANG
# 2  JOMBANG
# 3  JOMBANG
# 4  JOMBANG

# %%
pie2=datapie2['KAB/KOTA'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
pie2
# Out:
# KAB/KOTA LAINNYA    135
# SURABAYA            132
# BOJONEGORO           88
# TUBAN                87
# JOMBANG              82
# MOJOKERTO            80
# PAMEKASAN            70
# KOTA MALANG          62
# PACITAN              60
# TULUNGAGUNG          51
# SIDOARJO             48
# JEMBER               45
# PASURUAN             41
# MALANG               38
# KOTA BLITAR          34
# KOTA KEDIRI          28
# LAMONGAN             28
# BLITAR               27
# GRESIK               26
# PONOROGO             26
# KEDIRI               22
# PROBOLINGGO          22
# Name: KAB/KOTA, dtype: int64

# %%
pie2.plot.pie(autopct='%.1f%%', shadow=True, startangle=90, fontsize="large")
plt.title('Persentase Jumlah Peserta Pelatihan Dinas Koperasi dan UKM di Kabupaten/Kota Jawa Timur 2019')
# Out:
# Text(0.5, 1.0, 'Persentase Jumlah Peserta Pelatihan Dinas Koperasi dan UKM di Kabupaten/Kota Jawa Timur 2019')

# %%
data2 = pd.read_excel("D:/Document/Akademik/KP/analisis 2019.xlsx")
data2.head()
# Out:
#   KAB/KOTA  USIA                         JENIS PELATIHAN JENIS KELAMIN  \
# 0  JOMBANG  39.0  AKUNTANSI BERBASIS TEKNOLOGI INFORMASI             P
# 1  JOMBANG  56.0  AKUNTANSI BERBASIS TEKNOLOGI INFORMASI             P
# 2  JOMBANG  38.0  AKUNTANSI BERBASIS TEKNOLOGI INFORMASI             P
# 3  JOMBANG  40.0  AKUNTANSI BERBASIS TEKNOLOGI INFORMASI             P
# 4  JOMBANG  45.0  AKUNTANSI BERBASIS TEKNOLOGI INFORMASI             P
#
#   JANGKAUAN PEMASARAN
# 0                DESA
# 1                DESA
# 2                DESA
# 3                DESA
# 4           KECAMATAN

# %%
jkk=data2['JENIS KELAMIN'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
jkk
# Out:
# P    821
# L    411
# Name: JENIS KELAMIN, dtype: int64

# %%
kabkota2=data2['KAB/KOTA'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
kabkota2
# Out:
# SURABAYA            132
# BOJONEGORO           88
# TUBAN                87
# JOMBANG              82
# MOJOKERTO            80
# PAMEKASAN            70
# KOTA MALANG          62
# PACITAN              60
# TULUNGAGUNG          51
# SIDOARJO             48
# JEMBER               45
# PASURUAN             41
# MALANG               38
# KOTA BLITAR          34
# LAMONGAN             28
# KOTA KEDIRI          28
# BLITAR               27
# PONOROGO             26
# GRESIK               26
# PROBOLINGGO          22
# KEDIRI               22
# SUMENEP              20
# LUMAJANG             14
# KOTA MOJOKERTO       14
# MADIUN               12
# MAGETAN              11
# SITUBONDO             9
# BANYUWANGI            8
# KOTA PASURUAN         7
# BONDOWOSO             7
# NGANJUK               6
# TRENGGALEK            6
# KOTA PROBOLINGGO      5
# NGAWI                 5
# BATU                  5
# SAMPANG               4
# KOTA MADIUN           1
# BANGKALAN             1
# ...

# %%
jang2=data2['JANGKAUAN PEMASARAN'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
jang2
# Out:
# INSTANSI         372
# KABUPATEN        293
# PROVINSI         128
# DESA             115
# KECAMATAN         61
# NASIONAL          45
# INTERNASIONAL      4
# Name: JANGKAUAN PEMASARAN, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(kabkota2.values, kabkota2.index, alpha=1)
plt.show()

# %%
kabkota2.plot.pie(autopct='%.1f%%', shadow=True, startangle=140, fontsize="large")
plt.title('Kabupaten/Kota')
# Out:
# Text(0.5, 1.0, 'Kabupaten/Kota')

# %%
plt.figure(figsize=(15,10))
sns.barplot(jang2.values, jang2.index, alpha=1)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(jkk.index, jkk.values, alpha=1)
plt.show()

# %%
pel2=data2['JENIS PELATIHAN'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
pel2
# Out:
# KEWIRAUSAHAAN BAGI PEMUDA/MAHASISWA            402
# KEWIRAUSAHAAN                                  120
# AKUNTANSI BERBASIS TEKNOLOGI INFORMASI         112
# SKKNI BAGI MANAGER/KEPALA CABANG                63
# TAX PLANNING                                    60
# PEMBUKUAN SEDERHANA                             60
# BATIK WARNA ALAM                                60
# KEWIRAUSAHAAN BERBASIS KOPERASI                 60
# RESTRUKTURISASI USAHA KOPERASI                  60
# PELATIHAN BAGI CALON DEWAN PENGAWAS SYARIAH     44
# KOMUNIKASI BISNIS                               30
# BISNIS PLAN                                     30
# PENGAWASAN                                      30
# PERPAJAKAN                                      30
# PENGAWASAN KOPERASI                             30
# RKRAPBK                                         29
# SKKNI BAGI JURU BUKU                            12
# Name: JENIS PELATIHAN, dtype: int64

# %%
pel2.to_csv(r'D:\Document\Akademik\KP\Jenis Pelatihan.csv', index=False)

# %%
plt.figure(figsize=(15,10))
sns.barplot(pel2.values, pel2.index, alpha=1
           )
plt.show()

# %%
#2020

# %%
data3 = pd.read_excel("D:/Document/Akademik/KP/Analisis 2020.xlsx")
data3.head()
# Out:
#      KAB/KOTA JENIS KELAMIN   JABATAN  USIA JANGKAUAN PEMASARAN  \
# 0  BANYUWANGI             P  KARYAWAN    42            PROVINSI
# 1  BANYUWANGI             P  KARYAWAN    51            PROVINSI
# 2  BANYUWANGI             P  KARYAWAN    36            PROVINSI
# 3  BANYUWANGI             P  KARYAWAN    44            PROVINSI
# 4  BANYUWANGI             P  KARYAWAN    54            PROVINSI
#
#                                      JENIS PELATIHAN
# 0  ONE VILLAGE ONE PRODUCT (OVOP) KERAJINAN ANYAM...
# 1  ONE VILLAGE ONE PRODUCT (OVOP) KERAJINAN ANYAM...
# 2  ONE VILLAGE ONE PRODUCT (OVOP) KERAJINAN ANYAM...
# 3  ONE VILLAGE ONE PRODUCT (OVOP) KERAJINAN ANYAM...
# 4  ONE VILLAGE ONE PRODUCT (OVOP) KERAJINAN ANYAM...

# %%
kabkota3=data3['KAB/KOTA'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
kabkota3
# Out:
# BANYUWANGI     69
# PROBOLINGGO    11
# JEMBER         10
# BONDOWOSO       9
# LUMAJANG        9
# SITUBONDO       8
# Name: KAB/KOTA, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(kabkota3.values, kabkota3.index, alpha=1)
plt.show()

# %%
kabkota3.plot.pie(autopct='%.1f%%', shadow=True, startangle=140, fontsize="large")
plt.title('Kabupaten/Kota')
# Out:
# Text(0.5, 1.0, 'Kabupaten/Kota')

# %%
jang3=data3['JANGKAUAN PEMASARAN'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
jang3
# Out:
# KABUPATEN        45
# PROVINSI         33
# INTERNASIONAL    18
# INSTANSI         10
# KECAMATAN         8
# DESA              2
# Name: JANGKAUAN PEMASARAN, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(jang3.values, jang3.index, alpha=1)
plt.show()

# %%
pel3=data3['JENIS PELATIHAN'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
pel3
# Out:
# ONE VILLAGE ONE PRODUCT (OVOP) KERAJINAN ANYAMAN BAMBU    60
# ONE PESANTREN ONE PRODUCT (OPOP)                          56
# Name: JENIS PELATIHAN, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(pel3.values, pel3.index, alpha=1
           )
plt.show()

# %%
jk3=data3['JENIS KELAMIN'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
jk3
# Out:
# L    75
# P    41
# Name: JENIS KELAMIN, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.barplot(jk3.index, jk3.values, alpha=1)
plt.show()

# %%
jabat=data3['JABATAN'].value_counts(normalize=False,sort=True,ascending=False,bins=None,dropna=True)
jabat
# Out:
# KARYAWAN                       54
# KETUA                          25
# ANGGOTA                        13
# SEKRETARIS                      7
# REKANAN                         4
# BENDAHARA                       3
# OWNER                           1
# PENANGGUNG JAWAB                1
# PENGELOLA PRODUK                1
# KOOR. UNIT USAHA SABLON         1
# DIREKTUR                        1
# PENGAWAS                        1
# MANAJER                         1
# MARKETING                       1
# PENGURUS                        1
# KOOR. UNIT USAHA PERCETAKAN     1
# Name: JABATAN, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.barplot(jabat.values, jabat.index, alpha=1)
plt.show()

# %%
data5 = pd.read_excel("D:/Document/Akademik/KP/USER SIJAWARA.xlsx")
data5.head()
# Out:
#    No               NAMA  KAB/KOTA
# 0   1   artha mega utama  Lamongan
# 1   2     oding heryanto    Subang
# 2   3      Karno Santoso  Pasuruan
# 3   4  Nurul Fima Zahroh   Pacitan
# 4   5  mahendri arimurty  Ponorogo

# %%
cityy=data5["KAB/KOTA"].value_counts()
cityy
# Out:
# Pasuruan            43
# Malang              33
# Sidoarjo            32
# Madiun              31
# Mojokerto           27
# Surabaya            21
# Jember              20
# Ponorogo            16
# Trenggalek          15
# Gresik              14
# Kediri              14
# Probolinggo         12
# Jombang             11
# Lamongan            11
# Tuban               11
# Lumajang            10
# Pamekasan            9
# Blitar               9
# Ngawi                8
# Bojonegoro           6
# Batu                 6
# Banyuwangi           6
# Bangkalan            5
# Nganjuk              5
# Magetan              5
# Situbondo            4
# Bondowoso            4
# Tulungagung          4
# Pacitan              3
# Sampang              3
# Kota Pasuruan        3
# Sumenep              3
# Kota Probolinggo     2
# Samosir              2
# Kota Madiun          2
# Kota Malang          2
# Jakarta              2
# Semarang             1
# Denpasar             1
# Palembang            1
# ...

# %%
cityy.plot.pie(autopct='%.1f%%', shadow=True, startangle=140, fontsize="large")
plt.title('Kabupaten/Kota')
# Out:
# Text(0.5, 1.0, 'Kabupaten/Kota')

# %%
data4 = pd.read_excel("D:/Document/Akademik/KP/2020 piechart.xlsx")
data4.head()
# Out:
#            KAB/KOTA
# 0  Kab/Kota Lainnya
# 1   Luar Jawa Timur
# 2          Pasuruan
# 3  Kab/Kota Lainnya
# 4          Ponorogo

# %%
city=data4["KAB/KOTA"].value_counts()
city
# Out:
# Kab/Kota Lainnya    134
# Pasuruan             43
# Malang               33
# Sidoarjo             32
# Madiun               31
# Mojokerto            27
# Surabaya             21
# Jember               20
# Ponorogo             16
# Trenggalek           15
# Kediri               14
# Gresik               14
# Probolinggo          12
# Luar Jawa Timur      12
# Name: KAB/KOTA, dtype: int64

# %%
city.plot.pie(autopct='%.1f%%', shadow=True, startangle=140, fontsize="large")
plt.title('Persentase Jumlah Peserta Pelatihan Dinas Koperasi dan UKM di Kabupaten/Kota Jawa Timur 2020')
# Out:
# Text(0.5, 1.0, 'Persentase Jumlah Peserta Pelatihan Dinas Koperasi dan UKM di Kabupaten/Kota Jawa Timur 2020')

# %%
df2 = pd.DataFrame(np.array([[2017, 340], [2018, 120], [2019, 60], [2020, 316]]),
                   columns=['Tahun', 'JumlahPeserta'])
df2
# Out:
#    Tahun  JumlahPeserta
# 0   2017            340
# 1   2018            120
# 2   2019             60
# 3   2020            316

# %%
df2["Jumlah Peserta"]
# Out:
# 0    340
# 1    120
# 2     60
# 3    316
# Name: Jumlah Peserta, dtype: int32

# %%
g =sns.barplot(x='Tahun',y='JumlahPeserta',data=df2)

for index, row in df2.iterrows():
    g.text(row.name,row.JumlahPeserta, round(row.JumlahPeserta,2), color='black', ha="center")
    
plt.title("Jumlah Peserta Pelatihan Mei-Juni 2017-2020")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Mei-Juni 2017-2020')

# %%
data1018 = pd.read_excel("D:/Document/Akademik/KP/10 bawah 2018.xlsx")
data1018.head()
# Out:
#     KAB/KOTA  JUMLAH_PESERTA
# 0  SITUBONDO              11
# 1     BLITAR              11
# 2    JOMBANG              10
# 3     MADIUN              10
# 4  BONDOWOSO               8

# %%
gg =sns.barplot(x='KAB/KOTA',y='JUMLAH_PESERTA',data=data1018)

for index, row in data1018.iterrows():
    gg.text(row.name,row.JUMLAH_PESERTA, round(row.JUMLAH_PESERTA,2), color='black', ha="center")
    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2018")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2018')

# %%
datajauh18 = pd.read_excel("D:/Document/Akademik/KP/jauh 18.xlsx")
datajauh18.head()
# Out:
#      KAB/KOTA  JUMLAH_PESERTA
# 0     PACITAN               2
# 1     SUMENEP               6
# 2  BANYUWANGI              81
# 3    PONOROGO              67
# 4      JEMBER              73

# %%
g1 =sns.barplot(x='KAB/KOTA',y='JUMLAH_PESERTA',data=datajauh18)

for index, row in datajauh18.iterrows():
    g1.text(row.name,row.JUMLAH_PESERTA, round(row.JUMLAH_PESERTA,2), color='black', ha="center")
    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2018")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2018')

# %%
datajauh19 = pd.read_excel("D:/Document/Akademik/KP/jauh 19.xlsx")
datajauh19.head()
# Out:
#      KAB/KOTA  JUMLAH_PESERTA
# 0     PACITAN              60
# 1     SUMENEP              20
# 2  BANYUWANGI               8
# 3    PONOROGO              26
# 4      JEMBER              45

# %%
g2 =sns.barplot(x='KAB/KOTA',y='JUMLAH_PESERTA',data=datajauh19)

for index, row in datajauh19.iterrows():
    g2.text(row.name,row.JUMLAH_PESERTA, round(row.JUMLAH_PESERTA,2), color='black', ha="center")
    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2019")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2019')

# %%
datakabkota18 = pd.read_excel("D:/Document/Akademik/KP/kabkota18.xlsx")
datakabkota18.head()
# Out:
#       KAB/KOTA  JUMLAH_PESERTA
# 0      MAGETAN             126
# 1  KOTA MADIUN             119
# 2     SIDOARJO              96
# 3       KEDIRI              82
# 4   BANYUWANGI              81

# %%
plt.rcParams['figure.figsize']=[30,15]

# %%
g18 =sns.barplot(y='KAB/KOTA',x='JUMLAH_PESERTA',data=datakabkota18)
    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2018")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2018')

# %%
gg18 =sns.barplot(y='KAB/KOTA',x='JUMLAH_PESERTA',data=datakabkota18)

for index, row in datajauh19.iterrows():
    g2.text(row.name,row.JUMLAH_PESERTA, round(row.JUMLAH_PESERTA,2), color='black', ha="center")
    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2018")
# Out:
#   File "<ipython-input-4-63b4a7d3f28a>", line 1
#     gg18 =(y='KAB/KOTA',x='JUMLAH_PESERTA',data=datakabkota18)
#             ^
# SyntaxError: invalid syntax

# %%
datakabkota19 = pd.read_excel("D:/Document/Akademik/KP/kabkota19.xlsx")
datakabkota19.head()
# Out:
#      KAB/KOTA  JUMLAH_PESERTA
# 0    SURABAYA             132
# 1  BOJONEGORO              88
# 2       TUBAN              87
# 3     JOMBANG              82
# 4   MOJOKERTO              80

# %%
g19 =sns.barplot(y='KAB/KOTA',x='JUMLAH_PESERTA',data=datakabkota19)
    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2019")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2019')

# %%
datakabkota20 = pd.read_excel("D:/Document/Akademik/KP/kabkota20.xlsx")
datakabkota20.head()
# Out:
#       KAB/KOTA  JUMLAH_PESERTA
# 0   BANYUWANGI              69
# 1  PROBOLINGGO              11
# 2       JEMBER              10
# 3    BONDOWOSO               9
# 4     LUMAJANG               9

# %%
g20 =sns.barplot(y='KAB/KOTA',x='JUMLAH_PESERTA',data=datakabkota20)
    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2020")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Kab/Kota Jawa Timur 2020')

# %%
datakel18 = pd.read_excel("D:/Document/Akademik/Semester 7/KP/kelamin18.xlsx")
datakel18.head()
# Out:
#   Jenis_Kelamin  Jumlah_Peserta
# 0     Laki-laki             509
# 1     Perempuan            1339

# %%
k18 =sns.barplot(x='Jenis_Kelamin',y='Jumlah_Peserta',data=datakel18)

    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2018 berdasarkan Jenis Kelamin")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2018 berdasarkan Jenis Kelamin')

# %%
k18.plot.pie(autopct='%.1f%%', shadow=True, startangle=140, fontsize="large")
plt.title('Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2018 berdasarkan Jenis Kelamin')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-74ff305416d5> in <module>
# ----> 1 k18.plot.pie(autopct='%.1f%%', shadow=True, startangle=140, fontsize="large")
#       2 plt.title('Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2018 berdasarkan Jenis Kelamin')
#
# AttributeError: 'function' object has no attribute 'pie'

# %%
datakel19 = pd.read_excel("D:/Document/Akademik/KP/kelamin19.xlsx")
datakel19.head()
# Out:
#   Jenis_Kelamin  Jumlah_Peserta
# 0             L             411
# 1             P             821

# %%
k19 =sns.barplot(x='Jenis_Kelamin',y='Jumlah_Peserta',data=datakel19)


plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jenis Kelamin")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jenis Kelamin')

# %%
jkk.plot.pie(autopct='%.1f%%', shadow=True, startangle=140, fontsize="large")
plt.title('Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jenis Kelamin')
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jenis Kelamin')

# %%
datakel20 = pd.read_excel("D:/Document/Akademik/KP/kelamin20.xlsx")
datakel20.head()
# Out:
#   Jenis_Kelamin  Jumlah_Peserta
# 0             L              75
# 1             P              41

# %%
k20 =sns.barplot(x='Jenis_Kelamin',y='Jumlah_Peserta',data=datakel20)

plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jenis Kelamin")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jenis Kelamin')

# %%
jk3.plot.pie(autopct='%.1f%%', shadow=True, startangle=140, fontsize="large")
plt.title('Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jenis Kelamin')
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jenis Kelamin')

# %%
datajang18 = pd.read_excel("D:/Document/Akademik/Semester 7/KP/jangkauan18a.xlsx")
datajang18.head()
# Out:
#   Jangkauan Usaha  Jumlah_Peserta
# 0           LOKAL            1654
# 1        REGIONAL              99
# 2        NASIONAL              91
# 3   INTERNASIONAL               4

# %%
j18 =sns.barplot(x='Jangkauan Usaha',y='Jumlah_Peserta',data=datajang18)

for index, row in datajang18.iterrows():
    j18.text(row.name,row.Jumlah_Peserta, round(row.Jumlah_Peserta,2), color='black', ha="center")

plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2018 berdasarkan Jangkauan Usaha")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2018 berdasarkan Jangkauan Usaha')

# %%
datajang19 = pd.read_excel("D:/Document/Akademik/Semester 7/KP/jangkauan19a.xlsx")
datajang19.head()
# Out:
#   Jangkauan Usaha  Jumlah_Peserta
# 0           LOKAL            1055
# 1        REGIONAL             128
# 2        NASIONAL              45
# 3   INTERNASIONAL               4

# %%
j19 =sns.barplot(x='Jangkauan Usaha',y='Jumlah_Peserta',data=datajang19)

for index, row in datajang19.iterrows():
    j19.text(row.name,row.Jumlah_Peserta, round(row.Jumlah_Peserta,2), color='black', ha="center")
    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jangkauan Usaha")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jangkauan Usaha')

# %%
j19 =sns.barplot(x='Jangkauan_Pemasaran',y='Jumlah_Peserta',data=datajang19)

plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jangkauan Pemasaran")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jangkauan Pemasaran')

# %%
datajang20 = pd.read_excel("D:/Document/Akademik/Semester 7/KP/jangkauan20a.xlsx")
datajang20.head()
# Out:
#   Jangkauan Usaha  Jumlah_Peserta
# 0           LOKAL              65
# 1        REGIONAL              33
# 2   INTERNASIONAL              18

# %%
j20 =sns.barplot(x='Jangkauan Usaha',y='Jumlah_Peserta',data=datajang20)

for index, row in datajang20.iterrows():
    j20.text(row.name,row.Jumlah_Peserta, round(row.Jumlah_Peserta,2), color='black', ha="center")

plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jangkauan Usaha")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jangkauan Usaha')

# %%
datausaha18 = pd.read_excel("D:/Document/Akademik/Semester 7/KP/jenisusaha18.xlsx")
datausaha18.head()
# Out:
#   Jenis Usaha Koperasi  Jumlah_Peserta
# 0        Simpan Pinjam            1242
# 1             Produksi             284
# 2             Konsumsi             245
# 3          Serba Usaha              77

# %%
u18 =sns.barplot(x='Jenis Usaha Koperasi',y='Jumlah_Peserta',data=datausaha18)

for index, row in datausaha18.iterrows():
    u18.text(row.name,row.Jumlah_Peserta, round(row.Jumlah_Peserta,2), color='black', ha="center")

plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2018 berdasarkan Jenis Usaha")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2018 berdasarkan Jenis Usaha')

# %%
datausaha19 = pd.read_excel("D:/Document/Akademik/Semester 7/KP/jenisusaha19.xlsx")
datausaha19.head()
# Out:
#   Jenis Usaha Koperasi  Jumlah_Peserta
# 0             Konsumsi             558
# 1        Simpan Pinjam             356
# 2             Produksi             204
# 3          Serba Usaha             114

# %%
u19 =sns.barplot(x='Jenis Usaha Koperasi',y='Jumlah_Peserta',data=datausaha19)

for index, row in datausaha19.iterrows():
    u19.text(row.name,row.Jumlah_Peserta, round(row.Jumlah_Peserta,2), color='black', ha="center")

plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jenis Usaha")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jenis Usaha')

# %%
datausaha20 = pd.read_excel("D:/Document/Akademik/Semester 7/KP/jenisusaha20.xlsx")
datausaha20.head()
# Out:
#   Jenis Usaha Koperasi  Jumlah_Peserta
# 0             Produksi              85
# 1             Konsumsi              30
# 2          Serba Usaha               1

# %%
u20 =sns.barplot(x='Jenis Usaha Koperasi',y='Jumlah_Peserta',data=datausaha20)

for index, row in datausaha20.iterrows():
    u20.text(row.name,row.Jumlah_Peserta, round(row.Jumlah_Peserta,2), color='black', ha="center")

plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jenis Usaha")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jenis Usaha')

# %%
dataplt18 = pd.read_excel("D:/Document/Akademik/KP/pelatihan18.xlsx")
dataplt18.head()
# Out:
#                                Jenis_Pelatihan  Jumlah_Peserta
# 0                        AKUNTANSI BERBASIS IT             196
# 1                  AKUNTANSI BERBASIS KOMPUTER             180
# 2             MANAJEMEN SYARIAH DAN PENGAWASAN             120
# 3  PENGAWASAN DAN PENILAIAN KESEHATAN KOPERASI             120
# 4                      PELATIHAN DAN UJI SKKNI             111

# %%
p18 =sns.barplot(y='Jenis_Pelatihan',x='Jumlah_Peserta',data=dataplt18)
    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2018 berdasarkan Jenis Pelatihan")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2018 berdasarkan Jenis Pelatihan')

# %%
dataplt19 = pd.read_excel("D:/Document/Akademik/KP/pelatihan19.xlsx")
dataplt19.head()
# Out:
#                           Jenis_Pelatihan  Jumlah_Peserta
# 0     KEWIRAUSAHAAN BAGI PEMUDA/MAHASISWA             402
# 1                           KEWIRAUSAHAAN             120
# 2  AKUNTANSI BERBASIS TEKNOLOGI INFORMASI             112
# 3        SKKNI BAGI MANAGER/KEPALA CABANG              63
# 4                        BATIK WARNA ALAM              60

# %%
p19 =sns.barplot(y='Jenis_Pelatihan',x='Jumlah_Peserta',data=dataplt19)
    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jenis Pelatihan")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2019 berdasarkan Jenis Pelatihan')

# %%
dataplt20 = pd.read_excel("D:/Document/Akademik/Semester 7/KP/pelatihan20.xlsx")
dataplt20.head()
# Out:
#                                      Jenis_Pelatihan  Jumlah_Peserta
# 0                   ONE PESANTREN ONE PRODUCT (OPOP)              56
# 1  ONE VILLAGE ONE PRODUCT (OVOP) KERAJINAN ANYAM...              60

# %%
p20 =sns.barplot(x='Jenis_Pelatihan',y='Jumlah_Peserta',data=dataplt20)

for index, row in dataplt20.iterrows():
    p20.text(row.name,row.Jumlah_Peserta, round(row.Jumlah_Peserta,2), color='black', ha="center")

plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jenis Pelatihan")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jenis Pelatihan')

# %%
datajbt20 = pd.read_excel("D:/Document/Akademik/KP/jabatan20.xlsx")
datajbt20.head()
# Out:
#       Jabatan  Jumlah_Peserta
# 0    KARYAWAN              54
# 1       KETUA              25
# 2     ANGGOTA              13
# 3  SEKRETARIS               7
# 4     REKANAN               4

# %%
jb20 =sns.barplot(y='Jabatan',x='Jumlah_Peserta',data=datajbt20)
    
plt.title("Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jabatan")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Jabatan')

# %%
plt.rcParams['figure.figsize']=[15,8]

# %%
kabkotadaring = pd.read_excel("D:/Document/Akademik/KP/kabkota daring.xlsx")
kabkotadaring.head()
# Out:
#    KAB/KOTA  JUMLAH PESERTA
# 0    JEMBER              31
# 1    MADIUN              23
# 2  SIDOARJO              23
# 3    MALANG              21
# 4  PASURUAN              19

# %%
kabkotdar =sns.barplot(y='KAB/KOTA',x='JUMLAH PESERTA',data=kabkotadaring)
    
plt.title("Jumlah Peserta Pelatihan Webinar Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Kab/kota")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Webinar Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan Kab/kota')

# %%
kelamindaring = pd.read_excel("D:/Document/Akademik/KP/kelamin daring.xlsx")
kelamindaring.head()
# Out:
#   JENIS KELAMIN  JUMLAH PESERTA
# 0   LAKI - LAKI              74
# 1     PEREMPUAN              90

# %%
kelamindar =sns.barplot(x='JENIS KELAMIN',y='JUMLAH PESERTA',data=kelamindaring)
    
plt.title("Jumlah Peserta Pelatihan Webinar Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan jenis kelamin")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Webinar Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan jenis kelamin')

# %%
peldaring = pd.read_excel("D:/Document/Akademik/KP/pelatihan daring.xlsx")
peldaring.head()
# Out:
#            JENIS PELATIHAN  JUMLAH PESERTA
# 0            PERKOPERASIAN              73
# 1  THE POWER OF KOMUNIKASI             186

# %%
pelamindar =sns.barplot(x='JENIS PELATIHAN',y='JUMLAH PESERTA',data=peldaring)
    
plt.title("Jumlah Peserta Pelatihan Webinar Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan jenis pelatihan")
# Out:
# Text(0.5, 1.0, 'Jumlah Peserta Pelatihan Webinar Dinas Koperasi dan UKM Jawa Timur 2020 berdasarkan jenis pelatihan')

# %%
kabkota = pd.read_excel("D:/Document/Akademik//Semester 7/KP/data grafik.xlsx")
kabkota.head()
# Out:
#   Kabupaten/Kota  2018  2019  2020
# 0      BANGKALAN     4     1     0
# 1     BANYUWANGI    81     8    69
# 2           BATU    58     5     0
# 3         BLITAR    11    27     0
# 4     BOJONEGORO    23    88     0

# %%
labels = [Kabupaten]
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
labels = kabkota['Kabupaten/Kota']
a = kabkota[2018]
b = kabkota[2019]
c = kabkota[2020]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.5  # the width of the bars

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, a, width, label='2018')
rects2 = ax.bar(x + width/2, b, width, label='2019')
rects3 = ax.bar(x + width/2, c, width, label='2020')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

fig.tight_layout()

plt.show()
